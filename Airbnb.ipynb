# %% [markdown]
# AIRBNB ANALYSIS

# %% [markdown]
# #importing the library files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# IMPORTING THE CSV FILE

# %%
df = pd.read_csv("D:\\DATA SCIENCE ARJUN\\AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      19-10-2018               0.21                               6
# 1      21-05-2019               0.38                               2
# 2             NaN                NaN                               1
# 3      05-07-2019               4.64                               1
# 4      19-11-2018               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  19-10-2018
# 1  Entire home/apt    225               1                 45  21-05-2019
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  05-07-2019
# 4  Entire home/apt     80              10                  9  19-11-2018
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
#As we can observe above that by default the first 5 rows will get displayed

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 9          Ben           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  19-10-2018
# 1  Entire home/apt    225               1                 45  21-05-2019
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  05-07-2019
# 4  Entire home/apt     80              10                  9  19-11-2018
# 5  Entire home/apt    200               3                 74  22-06-2019
# 6     Private room     60              45                 49  05-10-2017
# 7     Private room     79               2                430  24-06-2019
# 8     Private room     79               2                118  21-07-2017
# 9  Entire home/apt    150               1                160  09-06-2019
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
# 6               0.40                               1                 0
# 7               3.47                               1               220
# 8               0.99                               1                 0
# 9               1.33                               4               188

# %%
#Since we have specified the number of rows in the brackets, the same will be displayed

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df[df.last_review.isna() & df.reviews_per_month.isna()].number_of_reviews.value_counts()
# Out:
# number_of_reviews
# 0    10052
# Name: count, dtype: int64

# %%
df.host_name.value_counts(dropna=False)
# Out:
# host_name
# Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: count, Length: 11453, dtype: int64

# %%
df.host_id.value_counts(dropna=False)
# Out:
# host_id
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: count, Length: 37457, dtype: int64

# %%
df.minimum_nights.describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
avg_month_length = 365/12
df['availability_months'] = df.availability_365 / avg_month_length

df['max_possible_bookings'] = df.availability_365 / df.minimum_nights
df['booking_estimate'] = df.reviews_per_month * df.availability_months

# %%
df = df[df.booking_estimate <= df.max_possible_bookings]

# %%
df['occupancy_percentage'] = (df.booking_estimate / df.max_possible_bookings) * 100
df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  19-10-2018
# 1  Entire home/apt    225               1                 45  21-05-2019
# 3  Entire home/apt     89               1                270  05-07-2019
# 4  Entire home/apt     80              10                  9  19-11-2018
# 5  Entire home/apt    200               3                 74  22-06-2019
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               0.38                               2               355
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
#
#    availability_months  max_possible_bookings  booking_estimate  \
# 0            12.000000                  365.0          2.520000
# 1            11.671233                  355.0          4.435068
# 3             6.378082                  194.0         29.594301
# 4             0.000000                    0.0          0.000000
# 5             4.241096                   43.0          2.502247
#
#    occupancy_percentage
# 0              0.690411
# 1              1.249315
# 3             15.254795
# 4                   NaN
# 5              5.819178

# %%
grouped = df[[
    'host_id',
    'host_name',
    'occupancy_percentage',
    'price'
    ,'neighbourhood_group',
    'neighbourhood'
]].groupby(['host_id','host_name'])

df_occupancy = grouped.agg({
    'occupancy_percentage':'mean',
    'price':'mean',
    'neighbourhood_group':pd.Series.mode,
    'neighbourhood':pd.Series.mode
}).reset_index()

# %%
Top_50 = df_occupancy.sort_values('occupancy_percentage',ascending=False).head(50)
Top_50
# Out:
#          host_id        host_name  occupancy_percentage   price  \
# 25717  154201505           Marcia             99.616438    92.0
# 13956   22223682             Zoey             98.630137   150.0
# 21647   73986440           Daniel             98.630137   150.0
# 2116     1190978     Linden & Bah             98.630137    52.0
# 29338  257674218            Jordi             98.630137   349.0
# 29885  268572259           Sergii             98.630137    79.0
# 11913   16105313            Debra             98.630137  5100.0
# 28610  232596712          Jessica             98.630137   583.0
# 16109   30933227            Dipti             98.630137   130.0
# 28900  243660343              Dan             98.630137   144.0
# 29325  257396181           Steven             98.630137   250.0
# 12868   18884557              A-B             98.630137   150.0
# 17232   36938850             Luke             98.630137   150.0
# 6533     5153401         Danielle             98.630137   160.0
# 26994  189994854            Ethan             98.630137   110.0
# 29650  263883589             Zach             98.630137   329.0
# 11528   15010630             Poma             98.630137   216.0
# 20640   61396454              Ash             98.630137   230.0
# 27311  200380610          Pranjal             98.630137   175.0
# 27754  214187963           Amanda             98.630137   217.5
# 23543  105506002   Martin & Steve             98.630137    44.0
# 23822  110448579           Moncef             98.630137    78.0
# 19953   53462017            Harry             98.630137   135.0
# 2923     1646818             Sara             98.630137   120.0
# 2376     1349266             Adam             98.630137   186.0
# 18384   43885531              Lee             98.630137   130.0
# 29298  256649546         Viberlyn             98.630137  2995.0
# 26279  165776960           Raanan             98.630137   130.0
# 29386  258230385         Vangelis             98.630137   176.0
# 7577     6602545            Eleni             98.630137   160.0
# 13635   21307389             Emma             98.630137   250.0
# 14274   23188519        Emily Wes             98.630137    68.0
# 29657  263957584             Sara             98.531507   198.0
# 29516  260879160            Safia             98.498630   160.0
# 6009     4427689             Nour             97.808219   129.0
# 1508      720558             Sara             97.578082   105.0
# 7718     6790229        Jean-Yves             96.986301   132.5
# 20708   62249912             Myra             96.657534   115.0
# 2202     1252131           Gianni             96.657534   199.0
# 9159     9287155             Nick             96.657534   450.0
# 23764  109402182          Michael             96.164384    59.0
# 22662   89767580               Jk             95.671233   250.0
# 14497   23952383             Jean             95.342466    75.0
# 820       303882             Brie             95.342466   130.0
# 14871   24911518            Erion             95.276712    96.0
# 12894   18985761          Abraham             95.046575    99.0
# 17212   36821356  Vitaly And Lena             94.816438    96.0
# 13366   20490026            Josie             94.684932    55.0
# 1319      593115             LuLu             94.684932   150.0
# 28771  238321374             Eyal             94.465753    60.0
#
#       neighbourhood_group       neighbourhood
# 25717            Brooklyn  Bedford-Stuyvesant
# 13956           Manhattan     Upper West Side
# 21647           Manhattan  Financial District
# 2116            Manhattan              Harlem
# 29338           Manhattan             Chelsea
# 29885            Brooklyn            Bushwick
# 11913           Manhattan             Midtown
# 28610           Manhattan     Upper West Side
# 16109           Manhattan            Kips Bay
# 28900           Manhattan              Harlem
# 29325           Manhattan             Midtown
# 12868           Manhattan        West Village
# 17232           Manhattan      Hell's Kitchen
# 6533             Brooklyn         Fort Greene
# 26994            Brooklyn             Gowanus
# 29650            Brooklyn         Boerum Hill
# 11528           Manhattan             Chelsea
# 20640           Manhattan             Midtown
# 27311           Manhattan             Chelsea
# 27754           Manhattan        West Village
# 23543            Brooklyn        Williamsburg
# 23822            Brooklyn            Flatbush
# 19953           Manhattan     Upper West Side
# 2923             Brooklyn        Williamsburg
# 2376             Brooklyn        Vinegar Hill
# 18384           Manhattan        East Village
# 29298           Manhattan             Chelsea
# 26279           Manhattan             Midtown
# 29386           Manhattan           Chinatown
# 7577             Brooklyn         South Slope
# 13635           Manhattan  Financial District
# 14274            Brooklyn  Bedford-Stuyvesant
# 29657            Brooklyn            Bushwick
# 29516           Manhattan     Lower East Side
# 6009            Manhattan      Hell's Kitchen
# 1508             Brooklyn         South Slope
# 7718             Brooklyn  Bedford-Stuyvesant
# 20708            Brooklyn         Fort Greene
# 2202            Manhattan            Kips Bay
# 9159            Manhattan            Kips Bay
# 23764           Manhattan              Harlem
# 22662           Manhattan             Midtown
# 14497            Brooklyn          Park Slope
# 820             Manhattan        East Village
# 14871           Manhattan         East Harlem
# 12894            Brooklyn     Carroll Gardens
# 17212            Brooklyn        Borough Park
# 13366              Queens           Sunnyside
# 1319             Brooklyn    Brooklyn Heights
# 28771           Manhattan     Upper West Side

# %%
Top_50.neighbourhood_group.value_counts()
# Out:
# neighbourhood_group
# Manhattan    30
# Brooklyn     19
# Queens        1
# Name: count, dtype: int64

# %%
df.neighbourhood_group.value_counts()
# Out:
# neighbourhood_group
# Manhattan        16410
# Brooklyn         16266
# Queens            4552
# Bronx              873
# Staten Island      311
# Name: count, dtype: int64

# %%
grouped = df[['occupancy_percentage','neighbourhood_group']].groupby('neighbourhood_group')
df_location_group = grouped.mean().reset_index()
df_location_group
# Out:
#   neighbourhood_group  occupancy_percentage
# 0               Bronx             14.186411
# 1            Brooklyn             14.944167
# 2           Manhattan             16.416093
# 3              Queens             15.043275
# 4       Staten Island             14.364924

# %%
plt.figure(figsize=(10,7))
plt.style.use('fivethirtyeight')
plt.bar(df_location_group.neighbourhood_group,df_location_group.occupancy_percentage,color='#009999',width=0.75)
plt.ylim(0,15)
plt.xlabel('Location')
plt.ylabel('occupancy')
plt.suptitle('Occupancy Percentage',y=1)
plt.title('Percentage of occupancy vs Location')
# Out:
# Text(0.5, 1.0, 'Percentage of occupancy vs Location')

# %%
grouped = df[['occupancy_percentage','neighbourhood']].groupby('neighbourhood')
df_location = grouped.mean().reset_index().sort_values(by='occupancy_percentage',ascending=False)
df_location
# Out:
#                   neighbourhood  occupancy_percentage
# 1                 Arden Heights             36.767123
# 139                New Brighton             35.020274
# 38            Claremont Village             31.699315
# 87                   Grant City             27.180822
# 163                Richmondtown             25.249315
# ..                          ...                   ...
# 206                  West Farms              2.334247
# 42                   Co-op City              1.660274
# 115                 Little Neck              1.402740
# 21                 Breezy Point              0.723288
# 9    Bay Terrace, Staten Island                   NaN
#
# [218 rows x 2 columns]

# %%
df['price_per_day'] = df.price / df.minimum_nights

# %%
plt.subplots(figsize=(16,8))
plt.subplot(1,2,1)
sns.distplot(df.price_per_day,kde=True)
plt.xlim([0,1000])
plt.subplot(1,2,2)
sns.distplot(df.number_of_reviews,kde=True)
plt.xlim([0,400])
# Out:
# (0.0, 400.0)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df.price_per_day,y=df.number_of_reviews)
# Out:
# <Axes: xlabel='price_per_day', ylabel='number_of_reviews'>

# %%
df.price_per_day.describe()
# Out:
# count    38412.000000
# mean        66.479525
# std        113.788363
# min          0.000000
# 25%         23.000000
# 50%         45.000000
# 75%         80.000000
# max       8000.000000
# Name: price_per_day, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df[df.price_per_day < 500].price_per_day)
# Out:
# <Axes: >

# %%
df = df[~((df.price_per_day == 0) | (df.price_per_day > 1000))]

# %%
def label(data):
    if data <= 25:
        return 'Very cheap'
    elif data > 25 and data <= 65:
        return 'Cheap'
    elif data > 65 and data <= 120:
        return 'Budget'
    elif data > 120 and data <= 200:
        return 'Expensive'
    else:
        return 'Very expensive'

df['price_per_day_labels'] = df.price_per_day.apply(label)
df.price_per_day_labels.value_counts(dropna=False).iloc[[1,0,2,3,4]]
# Out:
# price_per_day_labels
# Very cheap        10940
# Cheap             14541
# Budget             8213
# Expensive          3311
# Very expensive     1358
# Name: count, dtype: int64

# %%
grouped = df[['price_per_day_labels','number_of_reviews','occupancy_percentage']].groupby('price_per_day_labels')
df_price_range = grouped.agg({
    'number_of_reviews':'sum',
    'occupancy_percentage':'mean'
}).reset_index()
df_price_range
# Out:
#   price_per_day_labels  number_of_reviews  occupancy_percentage
# 0               Budget             290756             12.511032
# 1                Cheap             493580             14.555576
# 2            Expensive             103720             10.980822
# 3           Very cheap             190495             21.774206
# 4       Very expensive              35317              8.542661

# %%
total_reviews = sum(df_price_range.number_of_reviews)
df_price_range['reviews_percentage'] = df_price_range.number_of_reviews / total_reviews * 100
df_price_range = df_price_range.iloc[[3,1,0,2,4]]
df_price_range
# Out:
#   price_per_day_labels  number_of_reviews  occupancy_percentage  \
# 3           Very cheap             190495             21.774206
# 1                Cheap             493580             14.555576
# 0               Budget             290756             12.511032
# 2            Expensive             103720             10.980822
# 4       Very expensive              35317              8.542661
#
#    reviews_percentage
# 3           17.102116
# 1           44.312252
# 0           26.103273
# 2            9.311696
# 4            3.170663

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')
plt.bar(x=df_price_range.price_per_day_labels, height=df_price_range.reviews_percentage,color='#009999')
plt.title('Percentage of reviews vs per day Price',y=1.02)
plt.suptitle('Percentage of reviews recieved by listings of different per day price points',y=0.89)
plt.yticks([])
plt.ylabel('Percentage')
plt.xlabel('Price points')
# Out:
# Text(0.5, 0, 'Price points')

# %%
plt.figure(figsize=(12,8))
plt.style.use('fivethirtyeight')
plt.bar(x=df_price_range.price_per_day_labels, height=df_price_range.occupancy_percentage,color='#009999')
plt.title('Occupancy rates vs per day Price',y=1.02)
plt.suptitle('Percentage of occupancy distributed by per day price points',y=0.89)
plt.yticks([])
plt.ylabel('Percentage')
plt.xlabel('Price points')
# Out:
# Text(0.5, 0, 'Price points')
